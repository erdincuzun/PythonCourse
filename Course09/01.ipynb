# %%
import destek

# %%
destek.yaz("Merhaba")
# Out:
# Merhaba

# %%
import destek as d

# %%
d.yaz("Merhaba")
# Out:
# Merhaba

# %%
print(dir(d))
# Out:
# ['__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', 'yaz', 'yaz2']

# %%
import dosyalar

# %%
dosyalar
# Out:
# <module 'dosyalar' from 'C:\\Users\\Erdinç UZUN\\Desktop\\PythonDersi\\Ders09\\dosyalar\\__init__.py'>

# %%
from dosyalar import destek01

# %%
destek01.yaz101("Merhaba")
# Out:
# Merhaba

# %%
from dosyalar import destek02

# %%
destek02.yaz202("Merhaba 2")
# Out:
# Merhaba 2
